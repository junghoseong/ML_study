# %% [markdown]
# ## 4-3 Sarsa와 Q 학습을 활용한 미로 게임
# ### 4-3-1 Sarsa와 Q 학습으로 미로 게임 풀기
# '가치 반복법'은 어떤 행동을 선택할 때 다음 상태 가치와 현재 상태 가치의 차이를 계산하고, 그 차이만큼 현재 상태를 증가시키는 방법이다. <br>
# 대표적으로 `SARSA`와 `Q-Learning`이 있다. Sarsa는 수렴이 느리지만 국소적인 해답에 갇히지 않으며, Q-Learning은 수렴이 빠른 반면 국소적인 해답에 갇히기 쉽다.
#
# ### 4-3-2 수익과 할인 보상 합계
# 수익(Return)은 미래의 모든 지연 보상을 포함한 보상 합계이다.
# $$Return=R_{t+1}+R_{t+2}+R_{t+3}+...$$
# 보상은 환경에서 얻는 것에 비해 수익은 최대화하고자 하는 목표로써 에이전트가 스스로 설정한다.
#
# 할인 보상 합계(discounted return)은 자주 활용되는 예시다.
# $$Discounted_Return=R_{t+1}+\gamma \times R_{t+2}+\gamma^2 \times R_{t+3}+...$$
#
# ### 4-3-3 행동 가치 함수와 상태 가치 함수
#
# 수익은 아직 발생하지 않은, 미래에 일어날 가능성이 있는 일을 포함한 확정되지 않은 값이기 때문에 에이전트의 상태와 정책을 고정한 뒤 조건부로 수익을 계산한다. <br>
#
# 이 가치를 계산하는 함수에는 `행동 가치 함수`와 `상태 가치 함수`가 있다.
#
# - 행동 가치 함수
#
# Action Value Function은 특정한 상태에서 특정한 행동을 선택하는 가치를 계산하는 함수다. 행동 가치 함수는 기호 Q로 표시하므로 `Q 함수`라고 부른다. <br>
#
# 예를 들어 `s=5, a=down`일 때, 골인 지점에 도착하여 보상 1을 받는다면 식으로 다음과 같다.
# $$Q(s=5, a=down)=R_{t+1}=1$$
# 이 때, `a=left`를 선택한다면, 5->4->5->8과 같이 2개의 스텝을 밟기 위한 시간이 필요하다. 이는 식으로 다음과 같다.
# $$Q(s=5, a=left)=\gamma^2 \times1$$
# 에이전트가 4 구역에 있을 때, 골인 지점에 이르기 위해서는 4->5->8로 이동해야 한다. 이는 식으로 다음과 같다.
# $$Q(s=4, a=right)=R_{t+1} + \gamma \times Q(s=5, a=down) = 0 + \gamma \times 1 = \gamma$$
#
# - 상태 가치 함수
#
# State Value Function은 특정 상태의 가치를 계산하는 함수이다. 기호 V로 표현한다.<br>
# 예를 들어 `s=5, a=down`을 선택하면 보상 1을 받을 수 있다. 이는 식으로 다음과 같다.
# $$V(s=5)=R_{t+1}=1$$
# 에이전트가 4 구역에 있다면 4->5->8로 이동해야 하므로 식으로 다음과 같다.
# $$V(s=4)=R_{t+1} + \gamma \times V(s=5)=0 + \gamma \times 1 = \gamma$$
#
# ### 4-3-4 벨만 방정식과 마르코프 결정 과정
# Bellman Equation은 상태 가치 함수와 행동 가치 함수의 수식을 일반적인 형태로 바꾸어 쓴 식이다.
# $$ Q(s_t, a_t) = R_{t+1} + \gamma \times Q(s_{t+1}, a_{t+1})$$
# $$ V(s_t) = R_{t+1} + \gamma \times V(s_{t+1})$$
# 이 벨만 방정식이 성립하기 위해서는 환경이 Markov Decision Process를 따라야 한다.
# 벨만 방정식으로부터 행동 가치 함수를 학습하는 방법으로 SARSA, Q-Learning 등이 있다. 상태 가치 함수로는 Dueling Network, A2C 등의 학습 알고리즘을 사용하기도 한다.
#
# ### 4-3-5 가치 반복법 학습 순서
# 1. 랜덤 행동 준비
# 2. 행동 가치함수 준비
# 3. 행동에 따라 다음 상태 얻기
# 4. 랜덤 또는 행동 가치 함수에 따라 행동 얻기
# 5. 행동 가치 함수 갱신
# 6. 골인 지점에 이를 때 까지 3~5단계 반복
# 7. 에피소드 3~6을 반복하며 학습
#
# 행동 가치 함수가 충분히 학습되지 않은 상태에서 행동 가치 함수만으로 행동을 선택하면 발견하지 못한 좋은 선택을 간과할 수 있으므로 확률 $\epsilon$에 따라 무작위로 행동을 선택할 필요가 있다.
#
# ### 4-3-6 패키지 임포트

# %%
# 패키지 임포트
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import animation
from IPython.display import HTML

# %% [markdown]
# ### 4-3-7 미로 생성
# 그래프 표시 라이브러리 matplotlib을 사용하여 미로를 생성한다.

# %%
# 미로 생성
fig = plt.figure(figsize = (3, 3))

# 벽
plt.plot([0, 3],[3, 3], color='k')
plt.plot([0, 3],[0, 0], color='k')
plt.plot([0, 0],[0, 2], color='k')
plt.plot([3, 3],[1, 3], color='k')
plt.plot([1, 1],[1, 2], color='k')
plt.plot([2, 3],[2, 2], color='k')
plt.plot([2, 1],[1, 1], color='k')
plt.plot([2, 2],[0, 1], color='k')

# 숫자
for i in range(3):
    for j in range(3):
        plt.text(0.5 + i, 2.5 - j, str(i + j * 3), size=20, ha='center', va='center')
        
# 원
circle, = plt.plot([0.5], [2.5], marker='o', color='#d3d3d3', markersize=40)

# 눈금 및 배경 숨김
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, labelleft=False, left = False, right = False)
plt.box(False)

# %% [markdown]
# ### 4-3-8 랜덤 행동 준비
# 랜덤한 행동은 정책 경사법과 같이 파라미터 $\theta$, 정책을 생성하고, `np.random.choice()`로 분산을 추가해 생성한다. 단, 정책 경사법과 달리 파라미터와 정책은 갱신하지 않는다.

# %%
theta_0 = np.array([
    [np.nan, 1, 1, np.nan], # 0 상, 우, 하, 좌
    [np.nan, 1, 1, 1], # 1
    [np.nan, np.nan, np.nan, 1], # 2
    [1, np.nan, 1, np.nan], # 3
    [1, 1, np.nan, np.nan], # 4
    [np.nan, np.nan, 1, 1], # 5
    [1, 1, np.nan, np.nan], # 6
    [np.nan, np.nan, np.nan, 1], # 7
])
# 파라미터 theta를 정책으로 변환
def get_pi(theta):
    # 소프트맥스 함수로 변환
    [m, n] = theta.shape
    pi = np.zeros((m, n))
    exp_theta = np.exp(theta)
    
    for i in range(0, m):
        pi[i, :] = exp_theta[i, :] / np.nansum(exp_theta[i, :])
    
    pi = np.nan_to_num(pi)
    return pi

# 파라미터 theta의 초기값을 정책으로 변환
pi_0 = get_pi(theta_0)
print(pi_0)
# Out:
# [[0.         0.5        0.5        0.        ]
#  [0.         0.33333333 0.33333333 0.33333333]
#  [0.         0.         0.         1.        ]
#  [0.5        0.         0.5        0.        ]
#  [0.5        0.5        0.         0.        ]
#  [0.         0.         0.5        0.5       ]
#  [0.5        0.5        0.         0.        ]
#  [0.         0.         0.         1.        ]]

# %% [markdown]
# ### 4-3-9 행동에 따라 다음 상태 얻기

# %%
# 행동에 따라 다음 상태 얻기
def get_s_next(s, a):
    if a == 0: # 상
        return s - 3
    elif a == 1: # 우
        return s + 1
    elif a == 2: # 하
        return s + 3
    elif a == 3: # 좌
        return s - 1

# %% [markdown]
# ### 4-3-10 행동 가치 함수 준비
# 행동 가치 함수를 표현식으로 준비한다.

# %%
# 행동 가치 함수 준비
[a, b] = theta_0.shape
Q = np.random.rand(a, b) * theta_0
print(Q)
# Out:
# [[       nan 0.46920796 0.71475239        nan]
#  [       nan 0.25611643 0.54986019 0.82605199]
#  [       nan        nan        nan 0.99827219]
#  [0.95746033        nan 0.51401867        nan]
#  [0.68750295 0.49269784        nan        nan]
#  [       nan        nan 0.17642107 0.31802291]
#  [0.69408181 0.22280585        nan        nan]
#  [       nan        nan        nan 0.6817947 ]]

# %% [markdown]
# ### 4-3-11 랜덤 또는 행동 가치 함수에 따라 행동 얻기
# 확률 $\epsilon$으로 랜덤하게 행동을 선택하고, 확률 $1-\epsilon$에 따라 행동 가치 함수에서의 행동을 선택한다.

# %%
# 랜덤 또는 행동 가치 함수에 따라 행동 얻기
def get_a(s, Q, epsilon, pi_0):
    if np.random.rand() < epsilon:
        # 랜덤으로 행동 선택
        return np.random.choice([0, 1, 2, 3], p=pi_0[s])
    else:
        # 행동 가치 함수로 행동 선택
        return np.nanargmax(Q[s])

# %% [markdown]
# ### 4-3-12 Sarsa를 통한 행동 가치 함수 갱신
# 정책은 현재 상태에 따라 다음 행동을 결정하는 전략이다. Sarsa의 정책은 epsilon-greedy 정책이다. <br>
# Sarsa에서 행동 가치 함수를 갱신하는 계산식은 다음과 같다. 파라미터 $\theta$에 학습률과 TD 오차를 곱해서 그 값을 더한다. <br>
# $$Q(s_t, a_t) \leftarrow Q(s_t, a_t) + \eta \times (R_{t+1} + \gamma \times Q(s_{t+1}, a_{t+1}) - Q(s_t, a_t))$$
# `TD (Temporal Difference) 오차`란 행동 전의 평갓값과 행동 후의 평갓값의 차이를 의미한다. 최적화를 통해 TD 오차를 0에 가깝게 줄이면 행동에 대한 보상을 정확하게 예측할 수 있다. <br>

# %%
# Sarsa에 따른 행동 가치 함수 갱신
def sarsa(s, a, r, s_next, a_next, Q):
    eta = 0.1 # 학습 계수
    gamma = 0.9 # 시간 할인율
    
    if s_next == 8:
        Q[s ,a] = Q[s, a] + eta * (r - Q[s, a])
    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * Q[s_next, a_next] - Q[s, a])
    return Q

# %% [markdown]
# ### 4-3-13 Q 학습을 통한 행동 가치 함수 갱신
# Q 학습에서 행동 가치 함수를 갱신하는 계산식은 다음과 같다. 파라미터 $\theta$에 학습률과 TD 오차를 곱해서 그 값을 더한다. <br>
# $$Q(s_t, a_t) \leftarrow Q(s_t, a_t) + \eta \times (R_{t+1} + \gamma \times Q(s_{t+1}, a_{t+1}) - Q(s_t, a_t))$$
# Sarsa는 행동 가치 함수를 갱신할 때 '다음 스텝의 행동'을 사용하며, 다음 스텝의 행동을 계산할 때 epsilon-greedy에 따른 무작위성을 포함한다. <br>
# Q 학습에서는 행동 가치 함수를 갱신할 때, 무작위성을 포함하지 않는다. 때문에 Q-Learning이 더 빠르게 수렴하지만, 국소적인 정보에 갇히기 쉽다.

# %%
# Q 학습에 따른 행동 가치 함수 갱신
def q_learning(s, a, r, s_next, a_next, Q):
    eta = 0.1 # 학습 계수
    gamma = 0.9 # 시간 할인율
    
    if s_next == 8:
        Q[s ,a] = Q[s, a] + eta * (r - Q[s, a])
    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax[s_next, a_next] - Q[s, a])
    return Q

# %% [markdown]
# ### 4-3-14 1 에피소드 실행
# 1 에피소드를 실행해서 이력과 행동 가치 함수를 얻는다. 이력은 [상태, 행동] 리스트다.

# %%
# 1 에피소드 실행
def play(Q, epsilon, pi):
    s = 0 # 상태
    a = a_next = get_a(s, Q, epsilon, pi) # 행동 초깃값
    s_a_history = [[0, np.nan]] # 상태와 행동 이력
    
    # 에피소드 완료 시까지 반복
    while True:
        # 행동에 따른 다음 상태 얻기
        a = a_next
        s_next = get_s_next(s, a)
        
        # 이력 갱신
        s_a_history[-1][1] = a
        s_a_history.append([s_next, np.nan])
        
        # 종료 판정
        if s_next == 8:
            r = 1
            a_next = np.nan
        else:
            r = 0
            # 행동 가치 함수 Q에 따라 행동 얻기
            a_next = get_a(s_next, Q, epsilon, pi)
            
        # 행동 가치 함수 갱신(Q 학습 때에는 q_learning()으로 변경)
        Q = sarsa(s, a, r, s_next, a_next, Q)
        # Q = q_learning(s, a, s_next, a_next, Q)
        
        # 종료 판정
        if s_next == 8:
            break
        else:
            s = s_next
            
    # 이력과 행동 가치 함수 반환
    return [s_a_history, Q]

# %% [markdown]
# ### 4-3-15 에피소드 반복 실행을 통한 학습
# $\epsilon$-greedy 값을 초기값 0.5에서 진행될 때마다 2배로 점점 줄여간다.

# %%
epsilon = 0.5 # 초기값

# 에피소드를 반복해서 실행하며 학습
for episode in range(10):
    # epsilon-greedy 값을 점점 감소시킴
    epsilon = epsilon / 2
    
    # 1 에피소드를 실행해 이력과 행동 가치 함수 얻기
    [s_a_history, Q] = play(Q, epsilon, pi_0)
    
    # 출력
    print('에피소드: {}, 스텝 : {}'.format(episode, len(s_a_history) - 1))
# Out:
# 에피소드: 0, 스텝 : 746
# 에피소드: 1, 스텝 : 80
# 에피소드: 2, 스텝 : 52
# 에피소드: 3, 스텝 : 20
# 에피소드: 4, 스텝 : 18
# 에피소드: 5, 스텝 : 12
# 에피소드: 6, 스텝 : 4
# 에피소드: 7, 스텝 : 10
# 에피소드: 8, 스텝 : 10
# 에피소드: 9, 스텝 : 4

# %% [markdown]
# ### 4-2-15 애니메이션 표시
# -`animate()`
#
# `animate()`는 애니메이션 프레임별 처리를 수행하는 함수로 인수 `i`는 몇 번째 프레임인지를 의미한다. `Line2D`에서 제공하는 `circle`의 `set_data()`로 xy좌표를 갱신한다.
#
# - `animate.FuncAnimation`
#
# `animate.FuncAnimation`은 애니메이션을 생성하는 클래스다. 인수로는 `Figure`, 애니메이션의 정기적 처리를 수행하는 함수, 최대 프레임 수, 인터벌, 반복여부를 지정한다. <br>
# `to_jshtml()`를 이용하여 HTML로 변환한다.

# %%
# 애니메이션 정기 처리 수행 함수
def animate(i):
    state = s_a_history[i][0]
    circle.set_data((state % 3) + 0.5, 2.5 - int(state / 3))
    return circle

# 애니메이션 표시
anim = animation.FuncAnimation(fig, animate, frames=len(s_a_history), interval=200, repeat=False)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...
